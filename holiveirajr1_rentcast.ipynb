# %%
import os 
import seaborn as sns
import numpy as np
import pandas as pd
from dotenv import load_dotenv
import requests
import time
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt

# %%
load_dotenv()

rent_cast_api_key = os.getenv('API_KEY')

if rent_cast_api_key:
    print("API Key loaded successfully!")
else:
    print("API Key not found. Please check your .env file.")
# Out:
# API Key loaded successfully!

# %%
# # Property Records
# # Query Params
# state = 'FL'
# saleDateRange = '365'
# limit = 500  # Max limit per request
# offset = 0    # Starting offset
# total_properties = 145000  # Total number of properties you want
# properties = []  # List to store properties
# url = 'https://api.rentcast.io/v1/properties'

# %%
# # Function to get properties
# def get_properties(offset):
#     queryparams = {
#         'state': state,
#         'saleDateRange': saleDateRange,
#         'limit': limit,
#         'offset': offset
#     }
#     headers = {
#         "accept": "application/json",
#         "X-Api-Key": rent_cast_api_key
#     }
    
#     response = requests.get(url, headers=headers, params=queryparams)
    
#     # Check if response is successful
#     if response.status_code == 200:
#         data = response.json()
#         return data  # The response is already a list, so return it directly
#     else:
#         print(f"Error {response.status_code}: {response.text}")
#         return []

# %%
# # Loop through requests and get the properties
# while len(properties) < total_properties:
#     print(f"Getting properties: {len(properties)} / {total_properties}")
#     current_properties = get_properties(offset)
    
#     if not current_properties:
#         print("No more properties found.")
#         break
    
#     properties.extend(current_properties) 
#     offset += limit  
    
#     time.sleep(1)
# Out:
# Getting properties: 0 / 145000
# Error 401: {"status":401,"error":"auth/api-key-invalid","message":"The provided API key is not valid. Manage API keys on your API dashboard: https://app.rentcast.io/app/api"}
# No more properties found.

# %%
# Read in the .csv file
property_record_one = pd.read_csv('property_record_one.csv')
property_record_two = pd.read_csv('property_record_two.csv')

# %%
print(property_record_one.shape)
# Out:
# (72500, 29)

# %%
property_record_one.head()
# Out:
#                                                   id  \
# 0  2825-Palm-Beach-Blvd,-Apt-417,-Fort-Myers,-FL-...
# 1         3607-Bridgewood-Dr,-Jacksonville,-FL-32277
# 2              2025-Se-44th-St,-Cape-Coral,-FL-33904
# 3          4405-Granada-Blvd,-Coral-Gables,-FL-33146
# 4             11605-Sw-253rd-St,-Homestead,-FL-33032
#
#                                     formattedAddress          addressLine1  \
# 0  2825 Palm Beach Blvd, Apt 417, Fort Myers, FL ...  2825 Palm Beach Blvd
# 1         3607 Bridgewood Dr, Jacksonville, FL 32277    3607 Bridgewood Dr
# 2              2025 Se 44th St, Cape Coral, FL 33904       2025 Se 44th St
# 3          4405 Granada Blvd, Coral Gables, FL 33146     4405 Granada Blvd
# 4             11605 Sw 253rd St, Homestead, FL 33032     11605 Sw 253rd St
#
#   addressLine2          city state  zipCode      county   latitude  longitude  \
# 0      Apt 417    Fort Myers    FL    33916         Lee  26.652413 -81.855762
# 1          NaN  Jacksonville    FL    32277       Duval  30.363895 -81.610043
# 2          NaN    Cape Coral    FL    33904         Lee  26.568926 -81.932980
# 3          NaN  Coral Gables    FL    33146  Miami-Dade  25.731201 -80.271882
# 4          NaN     Homestead    FL    33032  Miami-Dade  25.532831 -80.379346
#
#    ...                    zoning              lastSaleDate  lastSalePrice  \
# 0  ...                       B-1  2024-03-15T00:00:00.000Z       315000.0
# 1  ...                       PUD  2024-03-15T00:00:00.000Z       345000.0
# 2  ...                      R1-W  2024-03-15T00:00:00.000Z       850000.0
# 3  ...   0100:SINGLE FAM,GENERAL  2024-03-15T00:00:00.000Z      4204000.0
# 4  ...  3700:MULTI-FAM,10-21 U/A  2024-03-15T00:00:00.000Z       445000.0
#
#                                             features  \
# 0  {'architectureType': 'Condo / Apartment', 'flo...
# 1  {'cooling': True, 'coolingType': 'Central', 'e...
# 2  {'architectureType': 'Ranch', 'cooling': True,...
# 3  {'exteriorType': 'Concrete Block', 'floorCount...
# 4                                  {'floorCount': 2}
#
#                                       taxAssessments  \
# 0  {'2019': {'year': 2019, 'value': 128393, 'impr...
# 1  {'2020': {'year': 2020, 'value': 158286, 'land...
# 2  {'2023': {'year': 2023, 'value': 848351, 'land...
# 3  {'2019': {'year': 2019, 'value': 1580456, 'lan...
# 4  {'2021': {'year': 2021, 'value': 212001}, '202...
#
#                                        propertyTaxes  \
# 0  {'2019': {'year': 2019, 'total': 2548}, '2022'...
# 1  {'2020': {'year': 2020, 'total': 2999}, '2021'...
# 2           {'2023': {'year': 2023, 'total': 10682}}
# 3  {'2019': {'year': 2019, 'total': 30859}, '2022...
# 4  {'2022': {'year': 2022, 'total': 5737}, '2023'...
#
#                                              history  \
# 0  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 1  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 2  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 3  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 4  {'2024-03-15': {'event': 'Sale', 'date': '2024...
#
#                                                owner ownerOccupied  hoa
# 0  {'names': ['Edgar K Collison', 'Muriel Colliso...         False  NaN
# 1  {'names': ['Jessielyn Wade', 'Gregory Wade'], ...          True  NaN
# 2  {'names': ['D&D PROPERTIES OF CAPE COLE INC'],...         False  NaN
# 3  {'names': ['NLU RADIX LLC'], 'type': 'Organiza...         False  NaN
# 4  {'names': ['Eliecer Ferrer', 'Anay Diaz'], 'ty...          True  NaN
#
# [5 rows x 29 columns]

# %%
property_record_two.head()
# Out:
#                                               id  \
# 0            7948-Pembroke-Rd,-Miramar,-FL-33023
# 1            2319-Orchid-Dr,-Davenport,-FL-33837
# 2            2388-Orchid-Dr,-Davenport,-FL-33837
# 3  3770-Branding-Iron-Bnd,-Saint-Cloud,-FL-34772
# 4            3902-SE-Fairway-W,-Stuart,-FL-34997
#
#                                 formattedAddress            addressLine1  \
# 0            7948 Pembroke Rd, Miramar, FL 33023        7948 Pembroke Rd
# 1            2319 Orchid Dr, Davenport, FL 33837          2319 Orchid Dr
# 2            2388 Orchid Dr, Davenport, FL 33837          2388 Orchid Dr
# 3  3770 Branding Iron Bnd, Saint Cloud, FL 34772  3770 Branding Iron Bnd
# 4            3902 SE Fairway W, Stuart, FL 34997       3902 SE Fairway W
#
#   addressLine2         city state  zipCode   county   latitude  longitude  \
# 0          NaN      Miramar    FL    33023  Broward  25.994338 -80.246085
# 1          NaN    Davenport    FL    33837     Polk  28.206452 -81.606291
# 2          NaN    Davenport    FL    33837     Polk  28.206452 -81.605422
# 3          NaN  Saint Cloud    FL    34772  Osceola  28.210286 -81.309582
# 4          NaN       Stuart    FL    34997   Martin  27.157402 -80.211506
#
#    ... zoning              lastSaleDate  lastSalePrice  \
# 0  ...    RM2  2024-05-24T00:00:00.000Z       330000.0
# 1  ...    NaN  2024-05-24T00:00:00.000Z       364500.0
# 2  ...    NaN  2024-05-24T00:00:00.000Z        64842.0
# 3  ...    NaN  2024-05-24T00:00:00.000Z       565795.0
# 4  ...    NaN  2024-05-24T00:00:00.000Z       540000.0
#
#                                             features  \
# 0  {'cooling': True, 'coolingType': 'Central', 'e...
# 1                                                NaN
# 2                              {'viewType': 'Water'}
# 3                                                NaN
# 4  {'architectureType': 'Duplex', 'cooling': True...
#
#                                       taxAssessments  \
# 0           {'2023': {'year': 2023, 'value': 62450}}
# 1  {'2023': {'year': 2023, 'value': 72000, 'land'...
# 2  {'2023': {'year': 2023, 'value': 82000, 'land'...
# 3  {'2023': {'year': 2023, 'value': 38000, 'land'...
# 4          {'2023': {'year': 2023, 'value': 201603}}
#
#                              propertyTaxes  \
# 0  {'2023': {'year': 2023, 'total': 1187}}
# 1  {'2023': {'year': 2023, 'total': 2719}}
# 2  {'2023': {'year': 2023, 'total': 2850}}
# 3  {'2023': {'year': 2023, 'total': 2233}}
# 4  {'2023': {'year': 2023, 'total': 3019}}
#
#                                              history  \
# 0  {'2024-05-24': {'event': 'Sale', 'date': '2024...
# 1  {'2024-05-24': {'event': 'Sale', 'date': '2024...
# 2  {'2024-05-24': {'event': 'Sale', 'date': '2024...
# 3  {'2024-05-24': {'event': 'Sale', 'date': '2024...
# 4  {'2024-05-24': {'event': 'Sale', 'date': '2024...
#
#                                                owner ownerOccupied  hoa
# 0  {'names': ['Steven Mosley', 'Jacqueline Mosley...          True  NaN
# 1  {'names': ['Andrew Sadlers', 'Elaine Christine...          True  NaN
# 2  {'names': ['NVR INC'], 'type': 'Organization',...         False  NaN
# 3  {'names': ['Jose Colon', 'Cynthia Colon'], 'ty...          True  NaN
# 4  {'names': ['Kenneth R Hatton', 'Grace S Hatton...         False  NaN
#
# [5 rows x 29 columns]

# %%
print(property_record_two.shape)
# Out:
# (72500, 29)

# %%
# conn = sqlite3.connect('property_database.db')  # Conn to SQL database

# # Turning the DataFrames into SQLite tables
# property_record_one.to_sql('property_record_one', conn, if_exists='replace', index=False)
# property_record_two.to_sql('property_record_two', conn, if_exists='replace', index=False)

# # Writing a SQL query to combine both tables
# query = """
#     SELECT * FROM property_record_one
#     UNION ALL
#     SELECT * FROM property_record_two;
# """

# # Converting SQL into a pandas Dataframe
# property_record_data = pd.read_sql(query, conn)

# print(property_record_data.head())

# conn.close()  # Close the connection to the SQLite
# Out:
#                                                   id  \
# 0  2825-Palm-Beach-Blvd,-Apt-417,-Fort-Myers,-FL-...
# 1         3607-Bridgewood-Dr,-Jacksonville,-FL-32277
# 2              2025-Se-44th-St,-Cape-Coral,-FL-33904
# 3          4405-Granada-Blvd,-Coral-Gables,-FL-33146
# 4             11605-Sw-253rd-St,-Homestead,-FL-33032
#
#                                     formattedAddress          addressLine1  \
# 0  2825 Palm Beach Blvd, Apt 417, Fort Myers, FL ...  2825 Palm Beach Blvd
# 1         3607 Bridgewood Dr, Jacksonville, FL 32277    3607 Bridgewood Dr
# 2              2025 Se 44th St, Cape Coral, FL 33904       2025 Se 44th St
# 3          4405 Granada Blvd, Coral Gables, FL 33146     4405 Granada Blvd
# 4             11605 Sw 253rd St, Homestead, FL 33032     11605 Sw 253rd St
#
#   addressLine2          city state  zipCode      county   latitude  longitude  \
# 0      Apt 417    Fort Myers    FL    33916         Lee  26.652413 -81.855762
# 1         None  Jacksonville    FL    32277       Duval  30.363895 -81.610043
# 2         None    Cape Coral    FL    33904         Lee  26.568926 -81.932980
# 3         None  Coral Gables    FL    33146  Miami-Dade  25.731201 -80.271882
# 4         None     Homestead    FL    33032  Miami-Dade  25.532831 -80.379346
#
#     propertyType  bedrooms  bathrooms  squareFootage  lotSize  yearBuilt  \
# 0          Condo       2.0        2.0         1003.0  44417.0     2006.0
# 1  Single Family       3.0        2.0         1921.0   4464.0     1992.0
# 2  Single Family       3.0        2.0         2050.0  12000.0     1967.0
# 3  Single Family       4.0        2.0         5087.0  15779.0     1951.0
# 4  Single Family       3.0        2.5         1740.0   1870.0     2016.0
#
#                assessorID                                   legalDescription  \
# 0  18-44-25-P1-03700.0417             ALTA MAR DESC INST#2006-83303 UNIT 417
# 1             128197-1276                38-58 38-2S-27E MARSH CREEK LOT 138
# 2  08-45-24-C3-00369.0550  CAPE CORAL UNIT 7 BLK.369 PB 12 PG 105 LOTS 55...
# 3        03-4119-001-6040  CORAL GABLES COUNTRY CLUB SEC 5 LOTS 13 & 14 &...
# 4        30-6030-003-7210  COCO PALM ESTATES PB 171-032 T-22608 LOT 5 BLK...
#
#                            subdivision                    zoning  \
# 0                  CITY RIVER DISTRICT                       B-1
# 1                          MARSH CREEK                       PUD
# 2  CAPE CORAL UNIT 7 EAST OF DEL PRADO                      R1-W
# 3   CORAL GABLES COUNTRY CLUB SEC PT 5   0100:SINGLE FAM,GENERAL
# 4                    COCO PALM ESTATES  3700:MULTI-FAM,10-21 U/A
#
#                lastSaleDate  lastSalePrice  \
# 0  2024-03-15T00:00:00.000Z       315000.0
# 1  2024-03-15T00:00:00.000Z       345000.0
# 2  2024-03-15T00:00:00.000Z       850000.0
# 3  2024-03-15T00:00:00.000Z      4204000.0
# 4  2024-03-15T00:00:00.000Z       445000.0
#
#                                             features  \
# 0  {'architectureType': 'Condo / Apartment', 'flo...
# 1  {'cooling': True, 'coolingType': 'Central', 'e...
# 2  {'architectureType': 'Ranch', 'cooling': True,...
# 3  {'exteriorType': 'Concrete Block', 'floorCount...
# 4                                  {'floorCount': 2}
#
#                                       taxAssessments  \
# 0  {'2019': {'year': 2019, 'value': 128393, 'impr...
# 1  {'2020': {'year': 2020, 'value': 158286, 'land...
# 2  {'2023': {'year': 2023, 'value': 848351, 'land...
# 3  {'2019': {'year': 2019, 'value': 1580456, 'lan...
# 4  {'2021': {'year': 2021, 'value': 212001}, '202...
#
#                                        propertyTaxes  \
# 0  {'2019': {'year': 2019, 'total': 2548}, '2022'...
# 1  {'2020': {'year': 2020, 'total': 2999}, '2021'...
# 2           {'2023': {'year': 2023, 'total': 10682}}
# 3  {'2019': {'year': 2019, 'total': 30859}, '2022...
# 4  {'2022': {'year': 2022, 'total': 5737}, '2023'...
#
#                                              history  \
# 0  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 1  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 2  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 3  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 4  {'2024-03-15': {'event': 'Sale', 'date': '2024...
#
#                                                owner  ownerOccupied   hoa
# 0  {'names': ['Edgar K Collison', 'Muriel Colliso...            0.0  None
# 1  {'names': ['Jessielyn Wade', 'Gregory Wade'], ...            1.0  None
# 2  {'names': ['D&D PROPERTIES OF CAPE COLE INC'],...            0.0  None
# 3  {'names': ['NLU RADIX LLC'], 'type': 'Organiza...            0.0  None
# 4  {'names': ['Eliecer Ferrer', 'Anay Diaz'], 'ty...            1.0  None

# %%
rent_cast_data = property_record_data

rent_cast_data.shape
# Out:
# (145000, 29)

# %%
rent_cast_data['history'].head()
# Out:
# 0    {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 1    {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 2    {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 3    {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 4    {'2024-03-15': {'event': 'Sale', 'date': '2024...
# Name: history, dtype: object

# %%
rent_cast_data['history'].nunique()
# Out:
# 84949

# %%
rent_cast_data['zoning'].head()
# Out:
# 0                         B-1
# 1                         PUD
# 2                        R1-W
# 3     0100:SINGLE FAM,GENERAL
# 4    3700:MULTI-FAM,10-21 U/A
# Name: zoning, dtype: object

# %%
rent_cast_data['zoning'].nunique()
# Out:
# 1578

# %%
rent_cast_data['zoning'].isna().sum()
# Out:
# np.int64(58515)

# %%
pd.set_option('display.max_columns', None)

rent_cast_data
# Out:
#                                                        id  \
# 0       2825-Palm-Beach-Blvd,-Apt-417,-Fort-Myers,-FL-...
# 1              3607-Bridgewood-Dr,-Jacksonville,-FL-32277
# 2                   2025-Se-44th-St,-Cape-Coral,-FL-33904
# 3               4405-Granada-Blvd,-Coral-Gables,-FL-33146
# 4                  11605-Sw-253rd-St,-Homestead,-FL-33032
# ...                                                   ...
# 144995                403-Britten-Dr,-Kissimmee,-FL-34758
# 144996               924-Hickory-Ave,-Inverness,-FL-34452
# 144997  8908-Cascade-Price-Cir,-North-Fort-Myers,-FL-3...
# 144998                3204-Oxmore-Dr,-Crestview,-FL-32539
# 144999            3039-Sandpiper-Ct,-Clearwater,-FL-33762
#
#                                          formattedAddress  \
# 0       2825 Palm Beach Blvd, Apt 417, Fort Myers, FL ...
# 1              3607 Bridgewood Dr, Jacksonville, FL 32277
# 2                   2025 Se 44th St, Cape Coral, FL 33904
# 3               4405 Granada Blvd, Coral Gables, FL 33146
# 4                  11605 Sw 253rd St, Homestead, FL 33032
# ...                                                   ...
# 144995                403 Britten Dr, Kissimmee, FL 34758
# 144996               924 Hickory Ave, Inverness, FL 34452
# 144997  8908 Cascade Price Cir, North Fort Myers, FL 3...
# 144998                3204 Oxmore Dr, Crestview, FL 32539
# 144999            3039 Sandpiper Ct, Clearwater, FL 33762
#
#                   addressLine1 addressLine2              city state  zipCode  \
# 0         2825 Palm Beach Blvd      Apt 417        Fort Myers    FL    33916
# 1           3607 Bridgewood Dr         None      Jacksonville    FL    32277
# 2              2025 Se 44th St         None        Cape Coral    FL    33904
# 3            4405 Granada Blvd         None      Coral Gables    FL    33146
# 4            11605 Sw 253rd St         None         Homestead    FL    33032
# ...                        ...          ...               ...   ...      ...
# 144995          403 Britten Dr         None         Kissimmee    FL    34758
# 144996         924 Hickory Ave         None         Inverness    FL    34452
# 144997  8908 Cascade Price Cir         None  North Fort Myers    FL    33917
# 144998          3204 Oxmore Dr         None         Crestview    FL    32539
# 144999       3039 Sandpiper Ct         None        Clearwater    FL    33762
#
#             county   latitude  longitude   propertyType  bedrooms  bathrooms  \
# 0              Lee  26.652413 -81.855762          Condo       2.0        2.0
# 1            Duval  30.363895 -81.610043  Single Family       3.0        2.0
# 2              Lee  26.568926 -81.932980  Single Family       3.0        2.0
# 3       Miami-Dade  25.731201 -80.271882  Single Family       4.0        2.0
# 4       Miami-Dade  25.532831 -80.379346  Single Family       3.0        2.5
# ...            ...        ...        ...            ...       ...        ...
# 144995     Osceola  28.155866 -81.492941  Single Family       4.0        2.0
# 144996      Citrus  28.820363 -82.326348  Single Family       2.0        2.0
# 144997         Lee  26.734284 -81.808256  Single Family       3.0        2.0
# 144998    Okaloosa  30.766810 -86.542021  Single Family       4.0        2.0
# 144999    Pinellas  27.905044 -82.675115  Single Family       4.0        2.0
#
#         squareFootage  lotSize  yearBuilt                   assessorID  \
# 0              1003.0  44417.0     2006.0       18-44-25-P1-03700.0417
# 1              1921.0   4464.0     1992.0                  128197-1276
# 2              2050.0  12000.0     1967.0       08-45-24-C3-00369.0550
# 3              5087.0  15779.0     1951.0             03-4119-001-6040
# 4              1740.0   1870.0     2016.0             30-6030-003-7210
# ...               ...      ...        ...                          ...
# 144995         2081.0   8494.0     2004.0           252628611213140020
# 144996         1211.0  14400.0     1988.0  20E-19S-21-0020-02280-018.0
# 144997         1671.0   7658.0     2021.0       15-43-25-L1-0500H.0270
# 144998         1609.0  19166.0     2025.0      10-3N-23-1000-000A-0220
# 144999         2569.0  13939.0     1983.0      02-30-16-85510-000-0600
#
#                                          legalDescription  \
# 0                  ALTA MAR DESC INST#2006-83303 UNIT 417
# 1                     38-58 38-2S-27E MARSH CREEK LOT 138
# 2       CAPE CORAL UNIT 7 BLK.369 PB 12 PG 105 LOTS 55...
# 3       CORAL GABLES COUNTRY CLUB SEC 5 LOTS 13 & 14 &...
# 4       COCO PALM ESTATES PB 171-032 T-22608 LOT 5 BLK...
# ...                                                   ...
# 144995  POINCIANA V 2 NBD 3 PB 3 PG 117 BLK 1314 LOT 2...
# 144996  INVERNESS HGLDS SOUTH PB 3 PG 51 LOTS 18 19 & ...
# 144997  NORTH BROOK PHASE ONE BLOCK H LOT 27 AS DESC I...
# 144998                      HOMEWOOD ESTATES BLK A LOT 22
# 144999                   STONEGATE UNIT I PHASE II LOT 60
#
#                                 subdivision                    zoning  \
# 0                       CITY RIVER DISTRICT                       B-1
# 1                               MARSH CREEK                       PUD
# 2       CAPE CORAL UNIT 7 EAST OF DEL PRADO                      R1-W
# 3        CORAL GABLES COUNTRY CLUB SEC PT 5   0100:SINGLE FAM,GENERAL
# 4                         COCO PALM ESTATES  3700:MULTI-FAM,10-21 U/A
# ...                                     ...                       ...
# 144995                    POINC VLG 2 NBD 3                      OPUD
# 144996            INVERNESS HIGHLANDS SOUTH  MDR MED DENSITY RESIDENT
# 144997                     NORTH BROOK PH 1                       RPD
# 144998                             HOMEWOOD                      None
# 144999            STONEGATE UNIT I PHASE II                      None
#
#                     lastSaleDate  lastSalePrice  \
# 0       2024-03-15T00:00:00.000Z       315000.0
# 1       2024-03-15T00:00:00.000Z       345000.0
# 2       2024-03-15T00:00:00.000Z       850000.0
# 3       2024-03-15T00:00:00.000Z      4204000.0
# 4       2024-03-15T00:00:00.000Z       445000.0
# ...                          ...            ...
# 144995  2025-01-27T00:00:00.000Z       210000.0
# 144996  2025-01-27T00:00:00.000Z       200000.0
# 144997  2025-01-27T00:00:00.000Z       429000.0
# 144998  2025-01-27T00:00:00.000Z        65000.0
# 144999  2025-01-27T00:00:00.000Z       515000.0
#
#                                                  features  \
# 0       {'architectureType': 'Condo / Apartment', 'flo...
# 1       {'cooling': True, 'coolingType': 'Central', 'e...
# 2       {'architectureType': 'Ranch', 'cooling': True,...
# 3       {'exteriorType': 'Concrete Block', 'floorCount...
# 4                                       {'floorCount': 2}
# ...                                                   ...
# 144995  {'cooling': True, 'coolingType': 'Package', 'e...
# 144996  {'cooling': True, 'coolingType': 'Commercial',...
# 144997  {'architectureType': 'Ranch', 'cooling': True,...
# 144998                                               None
# 144999  {'cooling': True, 'coolingType': 'Central', 'e...
#
#                                            taxAssessments  \
# 0       {'2019': {'year': 2019, 'value': 128393, 'impr...
# 1       {'2020': {'year': 2020, 'value': 158286, 'land...
# 2       {'2023': {'year': 2023, 'value': 848351, 'land...
# 3       {'2019': {'year': 2019, 'value': 1580456, 'lan...
# 4       {'2021': {'year': 2021, 'value': 212001}, '202...
# ...                                                   ...
# 144995  {'2022': {'year': 2022, 'value': 80959}, '2023...
# 144996  {'2022': {'year': 2022, 'value': 152497, 'land...
# 144997  {'2022': {'year': 2022, 'value': 246001, 'land...
# 144998  {'2022': {'year': 2022, 'value': 34291, 'land'...
# 144999          {'2022': {'year': 2022, 'value': 261284}}
#
#                                             propertyTaxes  \
# 0       {'2019': {'year': 2019, 'total': 2548}, '2022'...
# 1       {'2020': {'year': 2020, 'total': 2999}, '2021'...
# 2                {'2023': {'year': 2023, 'total': 10682}}
# 3       {'2019': {'year': 2019, 'total': 30859}, '2022...
# 4       {'2022': {'year': 2022, 'total': 5737}, '2023'...
# ...                                                   ...
# 144995  {'2022': {'year': 2022, 'total': 979}, '2023':...
# 144996  {'2022': {'year': 2022, 'total': 542}, '2024':...
# 144997  {'2022': {'year': 2022, 'total': 6489}, '2023'...
# 144998             {'2022': {'year': 2022, 'total': 348}}
# 144999            {'2022': {'year': 2022, 'total': 4322}}
#
#                                                   history  \
# 0       {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 1       {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 2       {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 3       {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 4       {'2024-03-15': {'event': 'Sale', 'date': '2024...
# ...                                                   ...
# 144995  {'2005-06-02': {'event': 'Sale', 'date': '2005...
# 144996  {'2025-01-27': {'event': 'Sale', 'date': '2025...
# 144997  {'2021-09-07': {'event': 'Sale', 'date': '2021...
# 144998  {'2025-01-27': {'event': 'Sale', 'date': '2025...
# 144999  {'1997-08-01': {'event': 'Sale', 'date': '1997...
#
#                                                     owner  ownerOccupied  \
# 0       {'names': ['Edgar K Collison', 'Muriel Colliso...            0.0
# 1       {'names': ['Jessielyn Wade', 'Gregory Wade'], ...            1.0
# 2       {'names': ['D&D PROPERTIES OF CAPE COLE INC'],...            0.0
# 3       {'names': ['NLU RADIX LLC'], 'type': 'Organiza...            0.0
# 4       {'names': ['Eliecer Ferrer', 'Anay Diaz'], 'ty...            1.0
# ...                                                   ...            ...
# 144995  {'names': ['Pablo Ocasio'], 'type': 'Individua...            1.0
# 144996  {'names': ['Arthur R Barlow', 'Karen R Barlow'...            1.0
# 144997  {'names': ['John S Emery', 'Amy H Emery'], 'ma...            1.0
# 144998  {'names': ['HOMEWOOD PROPERTIES LLC'], 'mailin...            0.0
# 144999  {'names': ['DAVID J TOBIN', 'LISA C TOBIN'], '...            1.0
#
#                 hoa
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ...             ...
# 144995  {'fee': 85}
# 144996         None
# 144997  {'fee': 99}
# 144998         None
# 144999         None
#
# [145000 rows x 29 columns]

# %%
rent_cast_data.columns
# Out:
# Index(['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city',
#        'state', 'zipCode', 'county', 'latitude', 'longitude', 'propertyType',
#        'bedrooms', 'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt',
#        'assessorID', 'legalDescription', 'subdivision', 'zoning',
#        'lastSaleDate', 'lastSalePrice', 'features', 'taxAssessments',
#        'propertyTaxes', 'history', 'owner', 'ownerOccupied', 'hoa'],
#       dtype='object')

# %%
rent_cast_data['lastSaleDate'] = pd.to_datetime(rent_cast_data['lastSaleDate'], errors='coerce')

rent_cast_data['month_year'] = rent_cast_data['lastSaleDate'].dt.to_period('M')

unique_sales_per_month = rent_cast_data.groupby('month_year').size()

print(unique_sales_per_month)
# Out:
# month_year
# 2024-03    14825
# 2024-04    32342
# 2024-05    31730
# 2024-06    27456
# 2024-07    21465
# 2024-08     3971
# 2024-09     2924
# 2024-10     3018
# 2024-11     2795
# 2024-12     2749
# 2025-01     1725
# Freq: M, dtype: int64
# /tmp/ipykernel_23340/2463849507.py:3: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   rent_cast_data['month_year'] = rent_cast_data['lastSaleDate'].dt.to_period('M')

# %%
number_of_nunique_cities = rent_cast_data['city'].nunique()
print(f'Number of unique cities are: {number_of_nunique_cities}')
# Out:
# Number of unique cities are: 578

# %%
number_of_nunique_propertytype = rent_cast_data['propertyType'].nunique()
print(f'Number of unique property type are: {number_of_nunique_propertytype}')

unique_propertytypes = rent_cast_data['propertyType'].unique()
print(f'The nunique property are:  {unique_propertytypes}')
# Out:
# Number of unique property type are: 7
# The nunique property are:  ['Condo' 'Single Family' 'Townhouse' 'Land' 'Multi-Family' 'Manufactured'
#  None 'Apartment']

# %%
property_type_counts = rent_cast_data['propertyType'].value_counts()

property_type_counts_sorted = property_type_counts.sort_values(ascending=False)

print("Number of properties sold for each propertyType (from greatest to least):")
print(property_type_counts_sorted)
# Out:
# Number of properties sold for each propertyType (from greatest to least):
# propertyType
# Single Family    99981
# Condo            22428
# Land             11797
# Manufactured      3772
# Multi-Family      2397
# Townhouse         1732
# Apartment          551
# Name: count, dtype: int64

# %%
# Step 1: Filter the data for 'Multi-Family' properties
multi_family_data = rent_cast_data[rent_cast_data['propertyType'] == 'Multi-Family']

# Step 2: Remove extreme outliers using the IQR method
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = multi_family_data['lastSalePrice'].quantile(0.25)
Q3 = multi_family_data['lastSalePrice'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the outlier thresholds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers based on IQR
multi_family_data_filtered = multi_family_data[(multi_family_data['lastSalePrice'] >= lower_bound) & 
                                               (multi_family_data['lastSalePrice'] <= upper_bound)]

# Step 3: Handle extreme values manually (capping at a reasonable threshold)
max_price_threshold = 10000000  # Capping max price at $10 million

# Apply manual filtering for extreme outliers above the threshold
multi_family_data_filtered = multi_family_data_filtered[multi_family_data_filtered['lastSalePrice'] <= max_price_threshold]

# Step 4: Define the price bins for more reasonable ranges
bins = [0, 50000, 100000, 150000, 200000, 250000, 300000, 500000, 1000000, 5000000, 10000000]
labels = ['0-50k', '50k-100k', '100k-150k', '150k-200k', '200k-250k', '250k-300k', '300k-500k', '500k-1M', '1M-5M', '5M-10M']

# Step 5: Create a new column for the price range category
multi_family_data_filtered['PriceRange'] = pd.cut(multi_family_data_filtered['lastSalePrice'], bins=bins, labels=labels)

# Step 6: Update the original rent_cast_data with the cleaned multi-family data
# Replace the original multi-family data with the filtered one
rent_cast_data.loc[rent_cast_data['propertyType'] == 'Multi-Family', :] = multi_family_data_filtered

# Step 7: Verify the update
print(f"Updated Multi-Family Data with Price Range Categories:\n{multi_family_data_filtered.head()}")
# Out:
# Updated Multi-Family Data with Price Range Categories:
#                                              id  \
# 37     19213-Tangerine-Rd,-Fort-Myers,-FL-33967
# 40       114-Christie-Ln,-Panama-City,-FL-32404
# 53    11888-N-Glenview-Ave,-Dunnellon,-FL-34433
# 105         405-E-4th-St,-Panama-City,-FL-32401
# 210  2821-Midnight-Pearl-Dr,-Sarasota,-FL-34240
#
#                                formattedAddress            addressLine1  \
# 37     19213 Tangerine Rd, Fort Myers, FL 33967      19213 Tangerine Rd
# 40       114 Christie Ln, Panama City, FL 32404         114 Christie Ln
# 53    11888 N Glenview Ave, Dunnellon, FL 34433    11888 N Glenview Ave
# 105         405 E 4th St, Panama City, FL 32401            405 E 4th St
# 210  2821 Midnight Pearl Dr, Sarasota, FL 34240  2821 Midnight Pearl Dr
#
#     addressLine2         city state  zipCode    county   latitude  longitude  \
# 37          None   Fort Myers    FL    33967       Lee  26.457837 -81.797473
# 40          None  Panama City    FL    32404       Bay  30.148405 -85.573077
# 53          None    Dunnellon    FL    34433    Citrus  29.036437 -82.482855
# 105         None  Panama City    FL    32401       Bay  30.155507 -85.655667
# 210         None     Sarasota    FL    34240  Sarasota  27.346491 -82.443881
#
#      propertyType  bedrooms  bathrooms  squareFootage  lotSize  yearBuilt  \
# 37   Multi-Family       4.0        2.0          898.0   8400.0     1983.0
# 40   Multi-Family       3.0        2.0         1092.0   4312.0     1990.0
# 53   Multi-Family       2.0        2.0         1740.0  54585.0     1968.0
# 105  Multi-Family       1.0        1.0         2080.0   5968.0     1946.0
# 210  Multi-Family       3.0        2.5          718.0   3220.0     2022.0
#
#                  assessorID  \
# 37   22-46-25-01-00271.0110
# 40            06513-018-000
# 53   18E-17S-03-4A0B0-004.0
# 105           20456-000-000
# 210            0214-05-0214
#
#                                       legalDescription  \
# 37   SAN CARLOS PK UT 19 UNREC BLK 271 OR 371 PG 47...
# 40   EASTGATE SUB PH II 131D3 N 36.14' OF LOT 4 BLK...
# 53                  AERO ESTS UNREC SUB LOTS 4-E & B-4
# 105      SUDDUTHS 1ST ADD. LOT 20 BLK 8 ORB 1256 P 962
# 210    LOT 214, BAY LANDING PHASE 2A, PB 54 PG 256-263
#
#                                  subdivision                 zoning  \
# 37   SAN CARLOS PARK UNITS 18, 19 (SC WOODS)                   TFC2
# 40                           EASTGATE SUB PH                   None
# 53             AERO ESTATES UNREC 3-17-18-NW  RUR RURAL RESIDENTIAL
# 105                         SUDDUTHS 1ST ADD                   PC02
# 210                                     None                   RSF4
#
#                  lastSaleDate  lastSalePrice  \
# 37  2024-03-15 00:00:00+00:00       440000.0
# 40  2024-03-15 00:00:00+00:00       174900.0
# 53  2024-03-15 00:00:00+00:00       180000.0
# 105 2024-03-15 00:00:00+00:00       365000.0
# 210 2024-03-15 00:00:00+00:00       412000.0
#
#                                               features  \
# 37   {'architectureType': 'Duplex', 'cooling': True...
# 40   {'cooling': True, 'coolingType': 'Central', 'e...
# 53   {'architectureType': 'Other', 'cooling': True,...
# 105  {'architectureType': 'Multi-Unit Building', 'c...
# 210  {'architectureType': 'Duplex', 'cooling': True...
#
#                                         taxAssessments  \
# 37   {'2019': {'year': 2019, 'value': 134037, 'land...
# 40   {'2019': {'year': 2019, 'value': 39196, 'land'...
# 53   {'2019': {'year': 2019, 'value': 77460, 'land'...
# 105  {'2022': {'year': 2022, 'value': 187786, 'land...
# 210  {'2022': {'year': 2022, 'value': 106600, 'land...
#
#                                          propertyTaxes  \
# 37   {'2019': {'year': 2019, 'total': 2545}, '2022'...
# 40   {'2019': {'year': 2019, 'total': 524}, '2022':...
# 53   {'2019': {'year': 2019, 'total': 1350}, '2020'...
# 105  {'2022': {'year': 2022, 'total': 1972}, '2023'...
# 210  {'2022': {'year': 2022, 'total': 1274}, '2023'...
#
#                                                history  \
# 37   {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 40   {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 53   {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 105  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 210  {'2024-03-15': {'event': 'Sale', 'date': '2024...
#
#                                                  owner  ownerOccupied   hoa  \
# 37   {'names': ['BRICK POINT MANAGEMENT LLC'], 'typ...            0.0  None
# 40   {'names': ['Justin Bevis', 'Sarah Rich'], 'typ...            1.0  None
# 53   {'names': ['Arthur Lutes', 'Helen Patricia Lut...            0.0  None
# 105  {'names': ['Charles Gaddis'], 'type': 'Individ...            0.0  None
# 210  {'names': ['Wilfred Nazario', 'Lisa Nazario'],...            1.0  None
#
#     month_year PriceRange
# 37     2024-03  300k-500k
# 40     2024-03  150k-200k
# 53     2024-03  150k-200k
# 105    2024-03  300k-500k
# 210    2024-03  300k-500k

# %%
rent_cast_data['propertyType'].value_counts()
# Out:
# propertyType
# Single Family    99981
# Condo            22428
# Land             11797
# Manufactured      3772
# Multi-Family      2189
# Townhouse         1732
# Apartment          551
# Name: count, dtype: int64

# %%
# Step 1: Filter the data for 'Single Family' properties
single_family_data = rent_cast_data[rent_cast_data['propertyType'] == 'Single Family']

# Step 2: Remove extreme outliers using the IQR method
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = single_family_data['lastSalePrice'].quantile(0.25)
Q3 = single_family_data['lastSalePrice'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the outlier thresholds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers based on IQR
single_family_data_filtered = single_family_data[(single_family_data['lastSalePrice'] >= lower_bound) & 
                                                 (single_family_data['lastSalePrice'] <= upper_bound)]

# Step 3: Handle extreme values manually (capping at a reasonable threshold)
max_price_threshold = 1000000  # Capping max price at $1 million

# Apply manual filtering for extreme outliers above the threshold
single_family_data_filtered = single_family_data_filtered[single_family_data_filtered['lastSalePrice'] <= max_price_threshold]

# Step 4: Define the price bins for more reasonable ranges
bins = [0, 50000, 100000, 150000, 200000, 250000, 300000, 500000, 1000000]
labels = ['0-50k', '50k-100k', '100k-150k', '150k-200k', '200k-250k', '250k-300k', '300k-500k', '500k-1M']

# Step 5: Create a new column for the price range category
single_family_data_filtered['PriceRange'] = pd.cut(single_family_data_filtered['lastSalePrice'], bins=bins, labels=labels)

# Step 6: Update the original rent_cast_data with the cleaned single-family data
# Replace the original single-family data with the filtered one
rent_cast_data.loc[rent_cast_data['propertyType'] == 'Single Family', :] = single_family_data_filtered

# Step 7: Verify the update
print(f"Updated Single Family Data with Price Range Categories:\n{single_family_data_filtered.head()}")
# Out:
# Updated Single Family Data with Price Range Categories:
#                                            id  \
# 1  3607-Bridgewood-Dr,-Jacksonville,-FL-32277
# 2       2025-Se-44th-St,-Cape-Coral,-FL-33904
# 4      11605-Sw-253rd-St,-Homestead,-FL-33032
# 6      1525-Larue-Ave,-Jacksonville,-FL-32207
# 8        2118-Estevez-Dr,-Lady-Lake,-FL-32159
#
#                              formattedAddress        addressLine1  \
# 1  3607 Bridgewood Dr, Jacksonville, FL 32277  3607 Bridgewood Dr
# 2       2025 Se 44th St, Cape Coral, FL 33904     2025 Se 44th St
# 4      11605 Sw 253rd St, Homestead, FL 33032   11605 Sw 253rd St
# 6      1525 Larue Ave, Jacksonville, FL 32207      1525 Larue Ave
# 8        2118 Estevez Dr, Lady Lake, FL 32159     2118 Estevez Dr
#
#   addressLine2          city state  zipCode      county   latitude  longitude  \
# 1         None  Jacksonville    FL  32277.0       Duval  30.363895 -81.610043
# 2         None    Cape Coral    FL  33904.0         Lee  26.568926 -81.932980
# 4         None     Homestead    FL  33032.0  Miami-Dade  25.532831 -80.379346
# 6         None  Jacksonville    FL  32207.0       Duval  30.310031 -81.659007
# 8         None     Lady Lake    FL  32159.0      Sumter  28.948389 -81.975813
#
#     propertyType  bedrooms  bathrooms  squareFootage  lotSize  yearBuilt  \
# 1  Single Family       3.0        2.0         1921.0   4464.0     1992.0
# 2  Single Family       3.0        2.0         2050.0  12000.0     1967.0
# 4  Single Family       3.0        2.5         1740.0   1870.0     2016.0
# 6  Single Family       3.0        1.0          990.0  11968.0     1926.0
# 8  Single Family       NaN        NaN         1121.0   3600.0     1997.0
#
#                assessorID                                   legalDescription  \
# 1             128197-1276                38-58 38-2S-27E MARSH CREEK LOT 138
# 2  08-45-24-C3-00369.0550  CAPE CORAL UNIT 7 BLK.369 PB 12 PG 105 LOTS 55...
# 4        30-6030-003-7210  COCO PALM ESTATES PB 171-032 T-22608 LOT 5 BLK...
# 6             080585-0000  8-15 44-2S-26E .276 R/P OKLAHOMA W 3FT OF S 50...
# 8                 D02A035  LOT 35 THE VILLAGES OF SUMTER VILLA VERA CRUZ ...
#
#                            subdivision                    zoning  \
# 1                          MARSH CREEK                       PUD
# 2  CAPE CORAL UNIT 7 EAST OF DEL PRADO                      R1-W
# 4                    COCO PALM ESTATES  3700:MULTI-FAM,10-21 U/A
# 6              OKLAHOMA, R/P PT BLK 12                     RMD-D
# 8        VILLAGES OF SUMTER VILLA VERA                      None
#
#                lastSaleDate  lastSalePrice  \
# 1 2024-03-15 00:00:00+00:00       345000.0
# 2 2024-03-15 00:00:00+00:00       850000.0
# 4 2024-03-15 00:00:00+00:00       445000.0
# 6 2024-03-15 00:00:00+00:00       700000.0
# 8 2024-03-15 00:00:00+00:00       272500.0
#
#                                             features  \
# 1  {'cooling': True, 'coolingType': 'Central', 'e...
# 2  {'architectureType': 'Ranch', 'cooling': True,...
# 4                                  {'floorCount': 2}
# 6  {'architectureType': 'Condo / Apartment', 'coo...
# 8  {'garage': True, 'garageSpaces': 2, 'garageTyp...
#
#                                       taxAssessments  \
# 1  {'2020': {'year': 2020, 'value': 158286, 'land...
# 2  {'2023': {'year': 2023, 'value': 848351, 'land...
# 4  {'2021': {'year': 2021, 'value': 212001}, '202...
# 6  {'2021': {'year': 2021, 'value': 267444, 'land...
# 8  {'2018': {'year': 2018, 'value': 114650}, '202...
#
#                                        propertyTaxes  \
# 1  {'2020': {'year': 2020, 'total': 2999}, '2021'...
# 2           {'2023': {'year': 2023, 'total': 10682}}
# 4  {'2022': {'year': 2022, 'total': 5737}, '2023'...
# 6  {'2022': {'year': 2022, 'total': 5684}, '2023'...
# 8  {'2020': {'year': 2020, 'total': 1592}, '2021'...
#
#                                              history  \
# 1  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 2  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 4  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 6  {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 8  {'2024-03-15': {'event': 'Sale', 'date': '2024...
#
#                                                owner  ownerOccupied   hoa  \
# 1  {'names': ['Jessielyn Wade', 'Gregory Wade'], ...            1.0  None
# 2  {'names': ['D&D PROPERTIES OF CAPE COLE INC'],...            0.0  None
# 4  {'names': ['Eliecer Ferrer', 'Anay Diaz'], 'ty...            1.0  None
# 6  {'names': ['MOXI PROPERTIES LLC'], 'type': 'Or...            0.0  None
# 8  {'names': ['Larry Galisky', 'Suzan Galisky'], ...            0.0  None
#
#   month_year PriceRange
# 1    2024-03  300k-500k
# 2    2024-03    500k-1M
# 4    2024-03  300k-500k
# 6    2024-03    500k-1M
# 8    2024-03  250k-300k

# %%
rent_cast_data['propertyType'].value_counts()
# Out:
# propertyType
# Single Family    91796
# Condo            22428
# Land             11797
# Manufactured      3772
# Multi-Family      2189
# Townhouse         1732
# Apartment          551
# Name: count, dtype: int64

# %%
import pandas as pd

# Step 1: Filter the data for 'Apartment' properties
apartment_data = rent_cast_data[rent_cast_data['propertyType'] == 'Apartment']

# Step 2: Remove extreme outliers using the IQR method
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = apartment_data['lastSalePrice'].quantile(0.25)
Q3 = apartment_data['lastSalePrice'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the outlier thresholds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers based on IQR
apartment_data_filtered = apartment_data[(apartment_data['lastSalePrice'] >= lower_bound) & 
                                         (apartment_data['lastSalePrice'] <= upper_bound)]

# Step 3: Handle extreme values manually (capping at a reasonable threshold)
max_price_threshold = 5000000  # Capping max price at $5 million

# Apply manual filtering for extreme outliers above the threshold
apartment_data_filtered = apartment_data_filtered[apartment_data_filtered['lastSalePrice'] <= max_price_threshold]

# Step 4: Define the price bins for more reasonable ranges
bins = [0, 50000, 100000, 150000, 200000, 250000, 300000, 500000, 1000000, 5000000]
labels = ['0-50k', '50k-100k', '100k-150k', '150k-200k', '200k-250k', '250k-300k', '300k-500k', '500k-1M', '1M-5M']

# Step 5: Create a new column for the price range category
apartment_data_filtered['PriceRange'] = pd.cut(apartment_data_filtered['lastSalePrice'], bins=bins, labels=labels)

# Step 6: Update the original rent_cast_data with the cleaned apartment data
# Replace the original apartment data with the filtered one
rent_cast_data.loc[rent_cast_data['propertyType'] == 'Apartment', :] = apartment_data_filtered

# Step 7: Verify the update
print(f"Updated Apartment Data with Price Range Categories:\n{apartment_data_filtered.head()}")
# Out:
# Updated Apartment Data with Price Range Categories:
#                                                     id  \
# 267          805-81st-St,-Apt-1,-Miami-Beach,-FL-33141
# 268          805-81st-St,-Apt-2,-Miami-Beach,-FL-33141
# 414             504-Chelsee-Way,-Lake-Placid,-FL-33852
# 1979               102-Fountain-Cv,-Leesburg,-FL-34748
# 2942  1001-Ne-8th-Ave,-Apt-204,-Delray-Beach,-FL-33483
#
#                                       formattedAddress     addressLine1  \
# 267          805 81st St, Apt 1, Miami Beach, FL 33141      805 81st St
# 268          805 81st St, Apt 2, Miami Beach, FL 33141      805 81st St
# 414             504 Chelsee Way, Lake Placid, FL 33852  504 Chelsee Way
# 1979               102 Fountain Cv, Leesburg, FL 34748  102 Fountain Cv
# 2942  1001 Ne 8th Ave, Apt 204, Delray Beach, FL 33483  1001 Ne 8th Ave
#
#      addressLine2          city state  zipCode      county   latitude  \
# 267         Apt 1   Miami Beach    FL  33141.0  Miami-Dade  25.866934
# 268         Apt 2   Miami Beach    FL  33141.0  Miami-Dade  25.866934
# 414          None   Lake Placid    FL  33852.0   Highlands  27.241486
# 1979         None      Leesburg    FL  34748.0        Lake  28.757426
# 2942      Apt 204  Delray Beach    FL  33483.0  Palm Beach  26.476041
#
#       longitude propertyType  bedrooms  bathrooms  squareFootage  lotSize  \
# 267  -80.127326    Apartment       1.0        1.0         1000.0   7000.0
# 268  -80.127326    Apartment       1.0        1.0         1000.0   7000.0
# 414  -81.330743    Apartment       2.0        2.0         1016.0   1073.0
# 1979 -81.869895    Apartment       2.0        2.0         1368.0   7924.0
# 2942 -80.065186    Apartment       1.0        1.0          615.0  39041.0
#
#       yearBuilt                assessorID  \
# 267      1952.0                      None
# 268      1952.0                      None
# 414      1993.0  C-21-37-30-010-0050-0040
# 1979     1974.0   12-20-24-0100-022-03700
# 2942     1968.0   12-43-46-09-58-000-2040
#
#                                        legalDescription  \
# 267                                                None
# 268                                                None
# 414   DEEANN LAKEFRONT ESTATES PB 15 PG 110 UNIT 4 B...
# 1979  HAWTHORNE AT LEESBURG A COOPERATIVE UNIT NO. L...
# 2942                        DELRAY COLONIAL INC APT 204
#
#                               subdivision zoning              lastSaleDate  \
# 267                                  None   None 2024-03-15 00:00:00+00:00
# 268                                  None   None 2024-03-15 00:00:00+00:00
# 414              DEEANN LAKEFRONT ESTATES     R3 2024-03-15 00:00:00+00:00
# 1979  HAWTHORNE AT LEESBURG A COOPERATIVE   None 2024-03-18 00:00:00+00:00
# 2942                  DELRAY COLONIAL INC   None 2024-03-19 00:00:00+00:00
#
#       lastSalePrice                                           features  \
# 267       1185000.0                                               None
# 268       1185000.0                                               None
# 414        165000.0  {'cooling': True, 'coolingType': 'Central', 'e...
# 1979       169000.0  {'cooling': True, 'coolingType': 'Central', 'e...
# 2942       230000.0       {'pool': True, 'poolType': 'Community Pool'}
#
#                                          taxAssessments  \
# 267                                                None
# 268                                                None
# 414            {'2023': {'year': 2023, 'value': 62132}}
# 1979           {'2023': {'year': 2023, 'value': 78870}}
# 2942  {'2020': {'year': 2020, 'value': 98000, 'impro...
#
#                                           propertyTaxes  \
# 267                                                None
# 268                                                None
# 414              {'2023': {'year': 2023, 'total': 372}}
# 1979            {'2023': {'year': 2023, 'total': 1146}}
# 2942  {'2020': {'year': 2020, 'total': 2153}, '2022'...
#
#                                                 history  \
# 267   {'2021-12-08': {'event': 'Sale', 'date': '2021...
# 268   {'2021-12-08': {'event': 'Sale', 'date': '2021...
# 414   {'2023-01-06': {'event': 'Sale', 'date': '2023...
# 1979  {'2024-03-18': {'event': 'Sale', 'date': '2024...
# 2942  {'2024-03-19': {'event': 'Sale', 'date': '2024...
#
#                                                   owner  ownerOccupied   hoa  \
# 267                                                None            NaN  None
# 268                                                None            NaN  None
# 414   {'names': ['Thomas E Estrin'], 'type': 'Indivi...            0.0  None
# 1979  {'names': ['Gerald D Yearack', 'Melanie A Year...            1.0  None
# 2942  {'names': ['Dallas H Wilt'], 'type': 'Individu...            0.0  None
#
#      month_year PriceRange
# 267     2024-03      1M-5M
# 268     2024-03      1M-5M
# 414     2024-03  150k-200k
# 1979    2024-03  150k-200k
# 2942    2024-03  200k-250k

# %%
rent_cast_data['propertyType'].value_counts()
# Out:
# propertyType
# Single Family    91796
# Condo            22428
# Land             11797
# Manufactured      3772
# Multi-Family      2189
# Townhouse         1732
# Apartment          462
# Name: count, dtype: int64

# %%
import pandas as pd

# Step 1: Filter the data for 'Land' properties
land_data = rent_cast_data[rent_cast_data['propertyType'] == 'Land']

# Step 2: Remove extreme outliers using the IQR method
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = land_data['lastSalePrice'].quantile(0.25)
Q3 = land_data['lastSalePrice'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the outlier thresholds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers based on IQR
land_data_filtered = land_data[(land_data['lastSalePrice'] >= lower_bound) & 
                                (land_data['lastSalePrice'] <= upper_bound)]

# Step 3: Handle extreme values manually (capping at a reasonable threshold)
max_price_threshold = 50000000  # Capping max price at $50 million

# Apply manual filtering for extreme outliers above the threshold
land_data_filtered = land_data_filtered[land_data_filtered['lastSalePrice'] <= max_price_threshold]

# Step 4: Define the price bins for more reasonable ranges
bins = [0, 50000, 100000, 150000, 200000, 250000, 300000, 500000, 1000000, 5000000, 50000000]
labels = ['0-50k', '50k-100k', '100k-150k', '150k-200k', '200k-250k', '250k-300k', 
          '300k-500k', '500k-1M', '1M-5M', '5M-50M']

# Step 5: Create a new column for the price range category
land_data_filtered['PriceRange'] = pd.cut(land_data_filtered['lastSalePrice'], bins=bins, labels=labels)

# Step 6: Update the original rent_cast_data with the cleaned land data
# Replace the original land data with the filtered one
rent_cast_data.loc[rent_cast_data['propertyType'] == 'Land', :] = land_data_filtered

# Step 7: Verify the update
print(f"Updated Land Data with Price Range Categories:\n{land_data_filtered.head()}")
# Out:
# Updated Land Data with Price Range Categories:
#                                          id  \
# 24     1505-Southwest-Rd,-Sanford,-FL-32771
# 31   8603-N-15th-St,-Apt-A,-Tampa,-FL-33604
# 52     11619-N-Bass-Rd,-Dunnellon,-FL-34433
# 94    7615-Excitement-Dr,-Reunion,-FL-34747
# 101      12090-74th-Ave,-Seminole,-FL-33772
#
#                            formattedAddress        addressLine1 addressLine2  \
# 24     1505 Southwest Rd, Sanford, FL 32771   1505 Southwest Rd         None
# 31   8603 N 15th St, Apt A, Tampa, FL 33604      8603 N 15th St        Apt A
# 52     11619 N Bass Rd, Dunnellon, FL 34433     11619 N Bass Rd         None
# 94    7615 Excitement Dr, Reunion, FL 34747  7615 Excitement Dr         None
# 101      12090 74th Ave, Seminole, FL 33772      12090 74th Ave         None
#
#           city state  zipCode        county   latitude  longitude  \
# 24     Sanford    FL  32771.0      Seminole  28.798091 -81.289133
# 31       Tampa    FL  33604.0  Hillsborough  28.028245 -82.442689
# 52   Dunnellon    FL  34433.0        Citrus  29.031833 -82.526692
# 94     Reunion    FL  34747.0       Osceola  28.266039 -81.582503
# 101   Seminole    FL  33772.0      Pinellas  27.839268 -82.806612
#
#     propertyType  bedrooms  bathrooms  squareFootage  lotSize  yearBuilt  \
# 24          Land       3.0        2.0         1420.0     45.0     2023.0
# 31          Land       3.0        2.0         1683.0   5250.0     1977.0
# 52          Land       3.0        2.0          672.0   8399.0     1978.0
# 94          Land       NaN        NaN            NaN   4966.0        NaN
# 101         Land       NaN        2.0          952.0  35684.0     1970.0
#
#                       assessorID  \
# 24        35-19-30-509-0000-0200
# 31        A19281945B000000000110
# 52   18E-17S-06-0130-000D0-020.0
# 94            352527483800011320
# 101           283015000003400400
#
#                                       legalDescription  \
# 24                         LOT 20 CATES ADD PB 3 PG 64
# 31   OAK TERRACE REVISED PLAT OF LOTS 11 AND 12 AND...
# 52   BACKWATERS HTS UNIT 3 LOT 20 BLK D DESC IN OR ...
# 94   REUNION PHASE 2 PARCEL 1 AND 1A PB 13 PGS 115-...
# 101  N 408FT(S) OF S 1297.02FT OF W 100FT OF E 400F...
#
#                      subdivision                     zoning  \
# 24                     CATES ADD                       None
# 31   OAK TERRACE REVISED PLAT OF                      RS-50
# 52      BACKWATER HEIGHTS UNIT 3  RURMH RURAL RESIDENTIAL M
# 94          REUNION PH 2 PL 1&1A                       OPUD
# 101            CRESTVIEW ESTATES                       None
#
#                  lastSaleDate  lastSalePrice  \
# 24  2024-03-15 00:00:00+00:00       328000.0
# 31  2024-03-15 00:00:00+00:00       345000.0
# 52  2024-03-15 00:00:00+00:00        23000.0
# 94  2024-03-15 00:00:00+00:00       118000.0
# 101 2024-03-15 00:00:00+00:00       344900.0
#
#                                               features  \
# 24                                                None
# 31   {'cooling': True, 'coolingType': 'Central', 'e...
# 52   {'architectureType': 'Mobile Home', 'exteriorT...
# 94                                                None
# 101  {'cooling': True, 'coolingType': 'Commercial',...
#
#                                         taxAssessments  \
# 24   {'2019': {'year': 2019, 'value': 7749}, '2022'...
# 31   {'2019': {'year': 2019, 'value': 13650, 'land'...
# 52   {'2019': {'year': 2019, 'value': 3000, 'land':...
# 94   {'2019': {'year': 2019, 'value': 58500, 'land'...
# 101          {'2022': {'year': 2022, 'value': 288911}}
#
#                                          propertyTaxes  \
# 24   {'2019': {'year': 2019, 'total': 135}, '2020':...
# 31   {'2019': {'year': 2019, 'total': 273}, '2022':...
# 52   {'2019': {'year': 2019, 'total': 48}, '2020': ...
# 94   {'2019': {'year': 2019, 'total': 3264}, '2022'...
# 101            {'2022': {'year': 2022, 'total': 5238}}
#
#                                                history  \
# 24   {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 31   {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 52   {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 94   {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 101  {'2021-02-24': {'event': 'Sale', 'date': '2021...
#
#                                                  owner  ownerOccupied   hoa  \
# 24   {'names': ['Wenese Pierre', 'Mavis Forbes'], '...            1.0  None
# 31   {'names': ['Jean Marie Poindexter'], 'type': '...            0.0  None
# 52   {'names': ['Joseph Gasaway'], 'type': 'Individ...            0.0  None
# 94   {'names': ['EXCITEMENT LLC'], 'type': 'Organiz...            0.0  None
# 101  {'names': ['EDWARD & KAREN SMITH LLC'], 'maili...            0.0  None
#
#     month_year PriceRange
# 24     2024-03  300k-500k
# 31     2024-03  300k-500k
# 52     2024-03      0-50k
# 94     2024-03  100k-150k
# 101    2024-03  300k-500k

# %%
rent_cast_data['propertyType'].value_counts()
# Out:
# propertyType
# Single Family    91796
# Condo            22428
# Land             10859
# Manufactured      3772
# Multi-Family      2189
# Townhouse         1732
# Apartment          462
# Name: count, dtype: int64

# %%
rent_cast_data.shape
# Out:
# (145000, 30)

# %%
rent_cast_data.isnull().sum().sort_values(ascending=False)
# Out:
# hoa                 134750
# addressLine2        121465
# zoning               64964
# features             40672
# subdivision          34707
# bedrooms             27322
# yearBuilt            26375
# lotSize              26227
# bathrooms            25766
# squareFootage        23599
# propertyTaxes        23170
# owner                22374
# ownerOccupied        22374
# legalDescription     22241
# assessorID           22123
# taxAssessments       22008
# history              18713
# propertyType         11762
# county                9530
# lastSalePrice         9426
# city                  9420
# state                 9420
# latitude              9420
# zipCode               9420
# longitude             9420
# id                    9420
# formattedAddress      9420
# addressLine1          9420
# lastSaleDate          9420
# month_year            9420
# dtype: int64

# %%
rent_cast_data.isnull().mean().sort_values(ascending=False) * 100
# Out:
# hoa                 92.931034
# addressLine2        83.768966
# zoning              44.802759
# features            28.049655
# subdivision         23.935862
# bedrooms            18.842759
# yearBuilt           18.189655
# lotSize             18.087586
# bathrooms           17.769655
# squareFootage       16.275172
# propertyTaxes       15.979310
# owner               15.430345
# ownerOccupied       15.430345
# legalDescription    15.338621
# assessorID          15.257241
# taxAssessments      15.177931
# history             12.905517
# propertyType         8.111724
# county               6.572414
# lastSalePrice        6.500690
# city                 6.496552
# state                6.496552
# latitude             6.496552
# zipCode              6.496552
# longitude            6.496552
# id                   6.496552
# formattedAddress     6.496552
# addressLine1         6.496552
# lastSaleDate         6.496552
# month_year           6.496552
# dtype: float64

# %%
rent_cast_data.duplicated().sum()
# Out:
# np.int64(9421)

# %%
rent_cast_data.drop_duplicates(inplace=True)

# %%
rent_cast_data.shape
# Out:
# (135579, 30)

# %%
rent_cast_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135579 entries, 0 to 144999
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                135578 non-null  object
#  1   formattedAddress  135578 non-null  object
#  2   addressLine1      135578 non-null  object
#  3   addressLine2      23535 non-null   object
#  4   city              135578 non-null  object
#  5   state             135578 non-null  object
#  6   zipCode           135578 non-null  float64
#  7   county            135468 non-null  object
#  8   latitude          135578 non-null  float64
#  9   longitude         135578 non-null  float64
#  10  propertyType      133236 non-null  object
#  11  bedrooms          117676 non-null  float64
#  12  bathrooms         119232 non-null  float64
#  13  squareFootage     121399 non-null  float64
#  14  lotSize           118771 non-null  float64
#  15  yearBuilt         118623 non-null  float64
#  16  assessorID        122875 non-null  object
#  17  legalDescription  122757 non-null  object
#  18  subdivision       110291 non-null  object
#  19  zoning            80035 non-null   object
#  20  lastSaleDate      135578 non-null  datetime64[ns, UTC]
#  21  lastSalePrice     135572 non-null  float64
#  22  features          104326 non-null  object
#  23  taxAssessments    122990 non-null  object
#  24  propertyTaxes     121828 non-null  object
#  25  history           126286 non-null  object
#  26  owner             122624 non-null  object
#  27  ownerOccupied     122624 non-null  float64
#  28  hoa               10250 non-null   object
#  29  month_year        135578 non-null  period[M]
# dtypes: datetime64[ns, UTC](1), float64(10), object(18), period[M](1)
# memory usage: 32.1+ MB

# %%
rent_cast_data.shape
# Out:
# (135579, 30)

# %%
rent_cast_data['propertyType'].value_counts()
# Out:
# propertyType
# Single Family    91794
# Condo            22428
# Land             10859
# Manufactured      3772
# Multi-Family      2189
# Townhouse         1732
# Apartment          462
# Name: count, dtype: int64

# %%
# Group by 'propertyType' and get summary statistics for 'lastSalePrice'
rent_cast_data.groupby('propertyType')['lastSalePrice'].describe()
# Out:
#                  count          mean           std     min       25%  \
# propertyType
# Apartment        462.0  5.930217e+05  5.882241e+05  5000.0  200000.0
# Condo          22425.0  4.862381e+05  2.554767e+06   310.0  185000.0
# Land           10859.0  3.483895e+05  2.370149e+05   510.0  125000.0
# Manufactured    3772.0  1.822608e+05  5.387799e+05   600.0   94000.0
# Multi-Family    2189.0  4.878665e+05  2.401201e+05  6000.0  320000.0
# Single Family  91794.0  4.073113e+05  1.897991e+05   300.0  285000.0
# Townhouse       1729.0  1.014355e+06  3.708900e+06   410.0  256000.0
#
#                     50%       75%          max
# propertyType
# Apartment      370000.0  749750.0    2943750.0
# Condo          280000.0  465600.0  345000000.0
# Land           355998.0  482832.5    1089700.0
# Manufactured   150000.0  209600.0   22500000.0
# Multi-Family   449000.0  620000.0    1255000.0
# Single Family  379990.0  511000.0     982500.0
# Townhouse      345800.0  479900.0   35714286.0

# %%
import matplotlib.pyplot as plt

# Create a bar plot of property types
rent_cast_data['propertyType'].value_counts().plot(kind='bar')
plt.title('Distribution of Property Types')
plt.xlabel('Property Type')
plt.ylabel('Sold')
plt.show()

# %%
rent_cast_data.describe()
# Out:
#              zipCode       latitude      longitude       bedrooms  \
# count  135578.000000  135578.000000  135578.000000  117676.000000
# mean    33470.094086      27.898255     -81.725649       2.924216
# std       809.168007       1.360220       1.323194       2.177589
# min     32003.000000      24.548661     -87.510316       0.000000
# 25%     32825.000000      26.678759     -82.333427       2.000000
# 50%     33541.000000      27.976532     -81.681432       3.000000
# 75%     33993.000000      28.721903     -80.727036       3.000000
# max     34997.000000      30.992581     -80.032459     486.000000
#
#            bathrooms  squareFootage       lotSize      yearBuilt  \
# count  119232.000000  121399.000000  1.187710e+05  118623.000000
# mean        2.101500    1628.138304  4.593665e+04    1990.219780
# std         2.898221    1146.565735  2.560545e+06      24.261202
# min         0.500000       1.000000  1.000000e+00     202.000000
# 25%         2.000000    1183.000000  5.521000e+03    1974.000000
# 50%         2.000000    1542.000000  7.841000e+03    1990.000000
# 75%         2.000000    1938.000000  1.089000e+04    2007.000000
# max       324.000000  277454.000000  6.000000e+08    2028.000000
#
#        lastSalePrice  ownerOccupied
# count   1.355720e+05  122624.000000
# mean    4.527171e+05       0.627830
# std     1.343884e+06       0.483385
# min     3.000000e+02       0.000000
# 25%     2.500000e+05       0.000000
# 50%     3.610000e+05       1.000000
# 75%     5.075000e+05       1.000000
# max     3.450000e+08       1.000000

# %%
rent_cast_data.columns
# Out:
# Index(['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city',
#        'state', 'zipCode', 'county', 'latitude', 'longitude', 'propertyType',
#        'bedrooms', 'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt',
#        'assessorID', 'legalDescription', 'subdivision', 'zoning',
#        'lastSaleDate', 'lastSalePrice', 'features', 'taxAssessments',
#        'propertyTaxes', 'history', 'owner', 'ownerOccupied', 'hoa',
#        'month_year'],
#       dtype='object')

# %%
rent_cast_data
# Out:
#                                                        id  \
# 0       2825-Palm-Beach-Blvd,-Apt-417,-Fort-Myers,-FL-...
# 1              3607-Bridgewood-Dr,-Jacksonville,-FL-32277
# 2                   2025-Se-44th-St,-Cape-Coral,-FL-33904
# 3                                                     NaN
# 4                  11605-Sw-253rd-St,-Homestead,-FL-33032
# ...                                                   ...
# 144995                403-Britten-Dr,-Kissimmee,-FL-34758
# 144996               924-Hickory-Ave,-Inverness,-FL-34452
# 144997  8908-Cascade-Price-Cir,-North-Fort-Myers,-FL-3...
# 144998                3204-Oxmore-Dr,-Crestview,-FL-32539
# 144999            3039-Sandpiper-Ct,-Clearwater,-FL-33762
#
#                                          formattedAddress  \
# 0       2825 Palm Beach Blvd, Apt 417, Fort Myers, FL ...
# 1              3607 Bridgewood Dr, Jacksonville, FL 32277
# 2                   2025 Se 44th St, Cape Coral, FL 33904
# 3                                                     NaN
# 4                  11605 Sw 253rd St, Homestead, FL 33032
# ...                                                   ...
# 144995                403 Britten Dr, Kissimmee, FL 34758
# 144996               924 Hickory Ave, Inverness, FL 34452
# 144997  8908 Cascade Price Cir, North Fort Myers, FL 3...
# 144998                3204 Oxmore Dr, Crestview, FL 32539
# 144999            3039 Sandpiper Ct, Clearwater, FL 33762
#
#                   addressLine1 addressLine2              city state  zipCode  \
# 0         2825 Palm Beach Blvd      Apt 417        Fort Myers    FL  33916.0
# 1           3607 Bridgewood Dr         None      Jacksonville    FL  32277.0
# 2              2025 Se 44th St         None        Cape Coral    FL  33904.0
# 3                          NaN          NaN               NaN   NaN      NaN
# 4            11605 Sw 253rd St         None         Homestead    FL  33032.0
# ...                        ...          ...               ...   ...      ...
# 144995          403 Britten Dr         None         Kissimmee    FL  34758.0
# 144996         924 Hickory Ave         None         Inverness    FL  34452.0
# 144997  8908 Cascade Price Cir         None  North Fort Myers    FL  33917.0
# 144998          3204 Oxmore Dr         None         Crestview    FL  32539.0
# 144999       3039 Sandpiper Ct         None        Clearwater    FL  33762.0
#
#             county   latitude  longitude   propertyType  bedrooms  bathrooms  \
# 0              Lee  26.652413 -81.855762          Condo       2.0        2.0
# 1            Duval  30.363895 -81.610043  Single Family       3.0        2.0
# 2              Lee  26.568926 -81.932980  Single Family       3.0        2.0
# 3              NaN        NaN        NaN            NaN       NaN        NaN
# 4       Miami-Dade  25.532831 -80.379346  Single Family       3.0        2.5
# ...            ...        ...        ...            ...       ...        ...
# 144995     Osceola  28.155866 -81.492941  Single Family       4.0        2.0
# 144996      Citrus  28.820363 -82.326348  Single Family       2.0        2.0
# 144997         Lee  26.734284 -81.808256  Single Family       3.0        2.0
# 144998    Okaloosa  30.766810 -86.542021  Single Family       4.0        2.0
# 144999    Pinellas  27.905044 -82.675115  Single Family       4.0        2.0
#
#         squareFootage  lotSize  yearBuilt                   assessorID  \
# 0              1003.0  44417.0     2006.0       18-44-25-P1-03700.0417
# 1              1921.0   4464.0     1992.0                  128197-1276
# 2              2050.0  12000.0     1967.0       08-45-24-C3-00369.0550
# 3                 NaN      NaN        NaN                          NaN
# 4              1740.0   1870.0     2016.0             30-6030-003-7210
# ...               ...      ...        ...                          ...
# 144995         2081.0   8494.0     2004.0           252628611213140020
# 144996         1211.0  14400.0     1988.0  20E-19S-21-0020-02280-018.0
# 144997         1671.0   7658.0     2021.0       15-43-25-L1-0500H.0270
# 144998         1609.0  19166.0     2025.0      10-3N-23-1000-000A-0220
# 144999         2569.0  13939.0     1983.0      02-30-16-85510-000-0600
#
#                                          legalDescription  \
# 0                  ALTA MAR DESC INST#2006-83303 UNIT 417
# 1                     38-58 38-2S-27E MARSH CREEK LOT 138
# 2       CAPE CORAL UNIT 7 BLK.369 PB 12 PG 105 LOTS 55...
# 3                                                     NaN
# 4       COCO PALM ESTATES PB 171-032 T-22608 LOT 5 BLK...
# ...                                                   ...
# 144995  POINCIANA V 2 NBD 3 PB 3 PG 117 BLK 1314 LOT 2...
# 144996  INVERNESS HGLDS SOUTH PB 3 PG 51 LOTS 18 19 & ...
# 144997  NORTH BROOK PHASE ONE BLOCK H LOT 27 AS DESC I...
# 144998                      HOMEWOOD ESTATES BLK A LOT 22
# 144999                   STONEGATE UNIT I PHASE II LOT 60
#
#                                 subdivision                    zoning  \
# 0                       CITY RIVER DISTRICT                       B-1
# 1                               MARSH CREEK                       PUD
# 2       CAPE CORAL UNIT 7 EAST OF DEL PRADO                      R1-W
# 3                                       NaN                       NaN
# 4                         COCO PALM ESTATES  3700:MULTI-FAM,10-21 U/A
# ...                                     ...                       ...
# 144995                    POINC VLG 2 NBD 3                      OPUD
# 144996            INVERNESS HIGHLANDS SOUTH  MDR MED DENSITY RESIDENT
# 144997                     NORTH BROOK PH 1                       RPD
# 144998                             HOMEWOOD                      None
# 144999            STONEGATE UNIT I PHASE II                      None
#
#                     lastSaleDate  lastSalePrice  \
# 0      2024-03-15 00:00:00+00:00       315000.0
# 1      2024-03-15 00:00:00+00:00       345000.0
# 2      2024-03-15 00:00:00+00:00       850000.0
# 3                            NaT            NaN
# 4      2024-03-15 00:00:00+00:00       445000.0
# ...                          ...            ...
# 144995 2025-01-27 00:00:00+00:00       210000.0
# 144996 2025-01-27 00:00:00+00:00       200000.0
# 144997 2025-01-27 00:00:00+00:00       429000.0
# 144998 2025-01-27 00:00:00+00:00        65000.0
# 144999 2025-01-27 00:00:00+00:00       515000.0
#
#                                                  features  \
# 0       {'architectureType': 'Condo / Apartment', 'flo...
# 1       {'cooling': True, 'coolingType': 'Central', 'e...
# 2       {'architectureType': 'Ranch', 'cooling': True,...
# 3                                                     NaN
# 4                                       {'floorCount': 2}
# ...                                                   ...
# 144995  {'cooling': True, 'coolingType': 'Package', 'e...
# 144996  {'cooling': True, 'coolingType': 'Commercial',...
# 144997  {'architectureType': 'Ranch', 'cooling': True,...
# 144998                                               None
# 144999  {'cooling': True, 'coolingType': 'Central', 'e...
#
#                                            taxAssessments  \
# 0       {'2019': {'year': 2019, 'value': 128393, 'impr...
# 1       {'2020': {'year': 2020, 'value': 158286, 'land...
# 2       {'2023': {'year': 2023, 'value': 848351, 'land...
# 3                                                     NaN
# 4       {'2021': {'year': 2021, 'value': 212001}, '202...
# ...                                                   ...
# 144995  {'2022': {'year': 2022, 'value': 80959}, '2023...
# 144996  {'2022': {'year': 2022, 'value': 152497, 'land...
# 144997  {'2022': {'year': 2022, 'value': 246001, 'land...
# 144998  {'2022': {'year': 2022, 'value': 34291, 'land'...
# 144999          {'2022': {'year': 2022, 'value': 261284}}
#
#                                             propertyTaxes  \
# 0       {'2019': {'year': 2019, 'total': 2548}, '2022'...
# 1       {'2020': {'year': 2020, 'total': 2999}, '2021'...
# 2                {'2023': {'year': 2023, 'total': 10682}}
# 3                                                     NaN
# 4       {'2022': {'year': 2022, 'total': 5737}, '2023'...
# ...                                                   ...
# 144995  {'2022': {'year': 2022, 'total': 979}, '2023':...
# 144996  {'2022': {'year': 2022, 'total': 542}, '2024':...
# 144997  {'2022': {'year': 2022, 'total': 6489}, '2023'...
# 144998             {'2022': {'year': 2022, 'total': 348}}
# 144999            {'2022': {'year': 2022, 'total': 4322}}
#
#                                                   history  \
# 0       {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 1       {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 2       {'2024-03-15': {'event': 'Sale', 'date': '2024...
# 3                                                     NaN
# 4       {'2024-03-15': {'event': 'Sale', 'date': '2024...
# ...                                                   ...
# 144995  {'2005-06-02': {'event': 'Sale', 'date': '2005...
# 144996  {'2025-01-27': {'event': 'Sale', 'date': '2025...
# 144997  {'2021-09-07': {'event': 'Sale', 'date': '2021...
# 144998  {'2025-01-27': {'event': 'Sale', 'date': '2025...
# 144999  {'1997-08-01': {'event': 'Sale', 'date': '1997...
#
#                                                     owner  ownerOccupied  \
# 0       {'names': ['Edgar K Collison', 'Muriel Colliso...            0.0
# 1       {'names': ['Jessielyn Wade', 'Gregory Wade'], ...            1.0
# 2       {'names': ['D&D PROPERTIES OF CAPE COLE INC'],...            0.0
# 3                                                     NaN            NaN
# 4       {'names': ['Eliecer Ferrer', 'Anay Diaz'], 'ty...            1.0
# ...                                                   ...            ...
# 144995  {'names': ['Pablo Ocasio'], 'type': 'Individua...            1.0
# 144996  {'names': ['Arthur R Barlow', 'Karen R Barlow'...            1.0
# 144997  {'names': ['John S Emery', 'Amy H Emery'], 'ma...            1.0
# 144998  {'names': ['HOMEWOOD PROPERTIES LLC'], 'mailin...            0.0
# 144999  {'names': ['DAVID J TOBIN', 'LISA C TOBIN'], '...            1.0
#
#                 hoa month_year
# 0              None    2024-03
# 1              None    2024-03
# 2              None    2024-03
# 3               NaN        NaT
# 4              None    2024-03
# ...             ...        ...
# 144995  {'fee': 85}    2025-01
# 144996         None    2025-01
# 144997  {'fee': 99}    2025-01
# 144998         None    2025-01
# 144999         None    2025-01
#
# [135579 rows x 30 columns]

# %%
#rent_cast_data_flattened = pd.json_normalize(rent_cast_data.to_dict(orient='records'), sep='_')

# Converting rent_cast_data_flattened back to rent_cast_data
#rent_cast_data_flattened.head()

# %%
#rent_cast_data_flattened = rent_cast_data

# %%
rent_cast_data.shape
# Out:
# (135579, 30)

# %%
rent_cast_data.columns
# Out:
# Index(['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city',
#        'state', 'zipCode', 'county', 'latitude', 'longitude', 'propertyType',
#        'bedrooms', 'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt',
#        'assessorID', 'legalDescription', 'subdivision', 'zoning',
#        'lastSaleDate', 'lastSalePrice', 'features', 'taxAssessments',
#        'propertyTaxes', 'history', 'owner', 'ownerOccupied', 'hoa',
#        'month_year'],
#       dtype='object')

# %%
rent_cast_data.columns
# Out:
# Index(['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city',
#        'state', 'zipCode', 'county', 'latitude', 'longitude', 'propertyType',
#        'bedrooms', 'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt',
#        'assessorID', 'legalDescription', 'subdivision', 'zoning',
#        'lastSaleDate', 'lastSalePrice', 'features', 'taxAssessments',
#        'propertyTaxes', 'history', 'owner', 'ownerOccupied', 'hoa',
#        'month_year'],
#       dtype='object')

# %%
# Drop the columns that are not useful for predicting price
columns_to_drop = [
    'id', 'assessorID', 'legalDescription', 'subdivision', 'owner', 'ownerOccupied', 'formattedAddress',
      'addressLine1', 'addressLine2'
]

rent_cast_data = rent_cast_data.drop(columns=columns_to_drop)

print(rent_cast_data.head())
# Out:
#            city state  zipCode      county   latitude  longitude  \
# 0    Fort Myers    FL  33916.0         Lee  26.652413 -81.855762
# 1  Jacksonville    FL  32277.0       Duval  30.363895 -81.610043
# 2    Cape Coral    FL  33904.0         Lee  26.568926 -81.932980
# 3           NaN   NaN      NaN         NaN        NaN        NaN
# 4     Homestead    FL  33032.0  Miami-Dade  25.532831 -80.379346
#
#     propertyType  bedrooms  bathrooms  squareFootage  lotSize  yearBuilt  \
# 0          Condo       2.0        2.0         1003.0  44417.0     2006.0
# 1  Single Family       3.0        2.0         1921.0   4464.0     1992.0
# 2  Single Family       3.0        2.0         2050.0  12000.0     1967.0
# 3            NaN       NaN        NaN            NaN      NaN        NaN
# 4  Single Family       3.0        2.5         1740.0   1870.0     2016.0
#
#                      zoning              lastSaleDate  lastSalePrice  \
# 0                       B-1 2024-03-15 00:00:00+00:00       315000.0
# 1                       PUD 2024-03-15 00:00:00+00:00       345000.0
# 2                      R1-W 2024-03-15 00:00:00+00:00       850000.0
# 3                       NaN                       NaT            NaN
# 4  3700:MULTI-FAM,10-21 U/A 2024-03-15 00:00:00+00:00       445000.0
#
#                                             features  \
# 0  {'architectureType': 'Condo / Apartment', 'flo...
# 1  {'cooling': True, 'coolingType': 'Central', 'e...
# 2  {'architectureType': 'Ranch', 'cooling': True,...
# 3                                                NaN
# 4                                  {'floorCount': 2}
#
#                                       taxAssessments  \
# 0  {'2019': {'year': 2019, 'value': 128393, 'impr...
# 1  {'2020': {'year': 2020, 'value': 158286, 'land...
# 2  {'2023': {'year': 2023, 'value': 848351, 'land...
# 3                                                NaN
# 4  {'2021': {'year': 2021, 'value': 212001}, '202...
#
#                                        propertyTaxes  \
# 0  {'2019': {'year': 2019, 'total': 2548}, '2022'...
# 1  {'2020': {'year': 2020, 'total': 2999}, '2021'...
# 2           {'2023': {'year': 2023, 'total': 10682}}
# 3                                                NaN
# 4  {'2022': {'year': 2022, 'total': 5737}, '2023'...
#
#                                              history   hoa month_year
# 0  {'2024-03-15': {'event': 'Sale', 'date': '2024...  None    2024-03
# 1  {'2024-03-15': {'event': 'Sale', 'date': '2024...  None    2024-03
# 2  {'2024-03-15': {'event': 'Sale', 'date': '2024...  None    2024-03
# 3                                                NaN   NaN        NaT
# 4  {'2024-03-15': {'event': 'Sale', 'date': '2024...  None    2024-03

# %%
rent_cast_data.shape
# Out:
# (135579, 21)

# %%
#rent_cast_data['lastSaleDate'] = pd.to_datetime(rent_cast_data['lastSaleDate'])

#rent_cast_data['year_month'] = rent_cast_data['lastSaleDate'].dt.to_period('M')

#m_rate = {
#  '2022-01': 0.6622, '2022-02': 0.6699, '2022-03': 0.6609, '2022-04': 0.6266,
#    '2022-05': 0.5906, '2022-06': 0.5736, '2022-07': 0.5544, '2022-08': 0.5483,
#    '2022-09': 0.5644, '2022-10': 0.6466, '2022-11': 0.6628, '2022-12': 0.6694,
#    '2023-01': 0.6734, '2023-02': 0.6980, '2023-03': 0.6832, '2023-04': 0.7453,
#    '2023-05': 0.7745, '2023-06': 0.8003, '2023-07': 0.8187, '2023-08': 0.8346,
#    '2023-09': 0.8684, '2023-10': 0.8684
#}

#rent_cast_data['year_month'] = rent_cast_data['year_month'].dt.strftime('%Y-%m')

#rent_cast_data['m_rate'] = rent_cast_data['year_month'].map(m_rate)

#rent_cast_data.head()

# %%
rent_cast_data.shape
# Out:
# (135579, 21)

# %%
rent_cast_data.columns
# Out:
# Index(['city', 'state', 'zipCode', 'county', 'latitude', 'longitude',
#        'propertyType', 'bedrooms', 'bathrooms', 'squareFootage', 'lotSize',
#        'yearBuilt', 'zoning', 'lastSaleDate', 'lastSalePrice', 'features',
#        'taxAssessments', 'propertyTaxes', 'history', 'hoa', 'month_year'],
#       dtype='object')

# %%
rent_cast_data.head()
# Out:
#            city state  zipCode      county   latitude  longitude  \
# 0    Fort Myers    FL  33916.0         Lee  26.652413 -81.855762
# 1  Jacksonville    FL  32277.0       Duval  30.363895 -81.610043
# 2    Cape Coral    FL  33904.0         Lee  26.568926 -81.932980
# 3           NaN   NaN      NaN         NaN        NaN        NaN
# 4     Homestead    FL  33032.0  Miami-Dade  25.532831 -80.379346
#
#     propertyType  bedrooms  bathrooms  squareFootage  lotSize  yearBuilt  \
# 0          Condo       2.0        2.0         1003.0  44417.0     2006.0
# 1  Single Family       3.0        2.0         1921.0   4464.0     1992.0
# 2  Single Family       3.0        2.0         2050.0  12000.0     1967.0
# 3            NaN       NaN        NaN            NaN      NaN        NaN
# 4  Single Family       3.0        2.5         1740.0   1870.0     2016.0
#
#                      zoning              lastSaleDate  lastSalePrice  \
# 0                       B-1 2024-03-15 00:00:00+00:00       315000.0
# 1                       PUD 2024-03-15 00:00:00+00:00       345000.0
# 2                      R1-W 2024-03-15 00:00:00+00:00       850000.0
# 3                       NaN                       NaT            NaN
# 4  3700:MULTI-FAM,10-21 U/A 2024-03-15 00:00:00+00:00       445000.0
#
#                                             features  \
# 0  {'architectureType': 'Condo / Apartment', 'flo...
# 1  {'cooling': True, 'coolingType': 'Central', 'e...
# 2  {'architectureType': 'Ranch', 'cooling': True,...
# 3                                                NaN
# 4                                  {'floorCount': 2}
#
#                                       taxAssessments  \
# 0  {'2019': {'year': 2019, 'value': 128393, 'impr...
# 1  {'2020': {'year': 2020, 'value': 158286, 'land...
# 2  {'2023': {'year': 2023, 'value': 848351, 'land...
# 3                                                NaN
# 4  {'2021': {'year': 2021, 'value': 212001}, '202...
#
#                                        propertyTaxes  \
# 0  {'2019': {'year': 2019, 'total': 2548}, '2022'...
# 1  {'2020': {'year': 2020, 'total': 2999}, '2021'...
# 2           {'2023': {'year': 2023, 'total': 10682}}
# 3                                                NaN
# 4  {'2022': {'year': 2022, 'total': 5737}, '2023'...
#
#                                              history   hoa month_year
# 0  {'2024-03-15': {'event': 'Sale', 'date': '2024...  None    2024-03
# 1  {'2024-03-15': {'event': 'Sale', 'date': '2024...  None    2024-03
# 2  {'2024-03-15': {'event': 'Sale', 'date': '2024...  None    2024-03
# 3                                                NaN   NaN        NaT
# 4  {'2024-03-15': {'event': 'Sale', 'date': '2024...  None    2024-03

# %%
rent_cast_data['zipCode'] = pd.to_numeric(rent_cast_data['zipCode'], errors='coerce').fillna(0).astype(int)

# %%
# # Use sparse matrix for one-hot encoding
# rent_cast_data_dummies = pd.get_dummies(
#     rent_cast_data[['city', 'state', 'zipCode', 'county', 'propertyType', 'zoning']], #history
#     sparse=True
# )

# # Check the result
# rent_cast_data_dummies.head()

# %%
# Correct way to select multiple columns
cols = [
    'city',
    'zipCode',
    'county',
    'propertyType',
    # 'history',
    # 'zoning',
]
rent_cast_data = pd.get_dummies(
    rent_cast_data[cols]
)

# Check the result
rent_cast_data.head()

# %%
# rent_cast_data = pd.get_dummies(rent_cast_data[
#     'city', 'state', 
#     'zipCode', 'county', 'propertyType', 'history', 'zoning', 'history'
# ])

# rent_cast_data.head()

# %%
rent_cast_data.dtypes
# Out:
# zipCode                   int64
# city_Alachua               bool
# city_Alford                bool
# city_Altamonte Springs     bool
# city_Altha                 bool
#                           ...
# zoning_YC                  bool
# zoning_YC-2                bool
# zoning_YC-4                bool
# zoning_YC-7                bool
# zoning_YC-8                bool
# Length: 2141, dtype: object

# %%
import psutil

# Check memory usage before and after a specific operation
print(f'Memory used before: {psutil.virtual_memory().percent}%')

# Perform your operation
# rent_cast_data = pd.get_dummies(rent_cast_data, columns=['column1', 'column2'])

print(f'Memory used after: {psutil.virtual_memory().percent}%')
# Out:
# Memory used before: 56.2%
# Memory used after: 56.2%
