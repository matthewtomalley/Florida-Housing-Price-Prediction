# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
import seaborn as sns

# %%
#df = pd.DataFrame()
#off_set = 0
#for i in range(4) :
#    url = f'https://api.rentcast.io/v1/properties?state=FL&limit=500&offset={off_set}'  
#
#    headers = {
#    "Accept" : "application/json",
#    "X-API-Key":"dcc30d3e7e454610af41d9e6ddddeea7"
#}
#
#    response  = requests.get(url, headers = headers)
#
#    if response.status_code == 200:
#        data = response.json()
#        data_df = pd.DataFrame(data)
#        df = pd.concat([df,data_df])
#        print(data)
#    else:
#        print(f"Error {response.status_code} - {response.text}")
#    
#    off_set += 500

# %%
#database of properties
off_set = 0
all_data = []
for i in range(300) :
    url = f'https://api.rentcast.io/v1/properties?state=FL&saleDateRange=365&limit=500&offset={off_set}'  

    headers = {
    "Accept" : "application/json",
    "X-API-Key":"00d1dc7344784d07aaf702d81bdd527f"
}

    response  = requests.get(url, headers = headers)

    if response.status_code == 200:
        data = response.json()
        all_data.extend(data)
        
    else:
        print(f"Error {response.status_code} - {response.text}")
    
    off_set += 500

df = pd.json_normalize(all_data)
df.to_csv("data.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[18], line 23
#      19         print(f"Error {response.status_code} - {response.text}")
#      21     off_set += 500
# ---> 23 df = pd.json_normalize(all_data)
#      24 df.to_csv("data.csv", index = False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/json/_normalize.py:457, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
#     451     record_path is None
#     452     and meta is None
#    (...)
#     455     and max_level is None
#     456 ):
# --> 457     return DataFrame(_simple_json_normalize(data, sep=sep))
#     459 if record_path is None:
# ...

# %%
df = pd.read_csv("./df_all.csv")

# %%
df['lastSaleDate'] = pd.to_datetime(df['lastSaleDate']).dt.normalize()

# %%
df["lastSaleDate"]
# Out:
# 0     2024-03-14 00:00:00+00:00
# 1     2024-03-14 00:00:00+00:00
# 2     2024-03-14 00:00:00+00:00
# 3     2024-03-14 00:00:00+00:00
# 4     2024-03-14 00:00:00+00:00
#                  ...
# 495   2024-03-14 00:00:00+00:00
# 496   2024-03-14 00:00:00+00:00
# 497   2024-03-14 00:00:00+00:00
# 498   2024-03-14 00:00:00+00:00
# 499   2024-03-14 00:00:00+00:00
# Name: lastSaleDate, Length: 500, dtype: datetime64[ns, UTC]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Columns: 236 entries, id to history.2022-04-21.price
# dtypes: datetime64[ns, UTC](1), float64(117), int64(2), object(116)
# memory usage: 922.0+ KB

# %%
df.drop("id", axis = 1).duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id                                      0
# formattedAddress                        0
# addressLine1                            0
# addressLine2                        28802
# city                                    0
#                                     ...
# taxAssessments.2011.value           49995
# taxAssessments.2011.land            49997
# taxAssessments.2011.improvements    49997
# propertyTaxes.2011.year             49999
# propertyTaxes.2011.total            49999
# Length: 135, dtype: int64

# %%
pd.set_option('display.max_columns', None)
df.describe(include='all').loc[["mean"]].round()

mean = df.describe(include='all').loc[["mean"]].round()

for col in df.columns:
     if col in mean.columns:
         if pd.api.types.is_numeric_dtype(df[col]):
              df[col] = df[col].fillna(mean[col].values[0])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df_clean = df.isnull().sum()

# %%
to_drop = df.isnull().sum()

# %%
df_clean = df.drop(columns=to_drop[to_drop > 0].index)

# %%
df_clean.head()
# Out:
#                                            id  \
# 0        1015-Ohaha-Way,-North-Port,-FL-34289
# 1           637-S-5th-Ave,-Wauchula,-FL-33873
# 2       100-Park-Crest-Ter,-Sebring,-FL-33870
# 3  2010-Village-Grove-Blvd,-Sebring,-FL-33870
# 4          829-Lime-Ave,-Frostproof,-FL-33843
#
#                              formattedAddress             addressLine1  \
# 0        1015 Ohaha Way, North Port, FL 34289           1015 Ohaha Way
# 1           637 S 5th Ave, Wauchula, FL 33873            637 S 5th Ave
# 2       100 Park Crest Ter, Sebring, FL 33870       100 Park Crest Ter
# 3  2010 Village Grove Blvd, Sebring, FL 33870  2010 Village Grove Blvd
# 4          829 Lime Ave, Frostproof, FL 33843             829 Lime Ave
#
#          city state  zipCode            county   latitude  longitude  \
# 0  North Port    FL    34289   Sarasota County  27.085560 -82.152810
# 1    Wauchula    FL    33873     Hardee County  27.541410 -81.806750
# ...

# %%
df_clean.isnull().sum()
# Out:
# id                                  0
# formattedAddress                    0
# addressLine1                        0
# city                                0
# state                               0
# zipCode                             0
# county                              0
# latitude                            0
# longitude                           0
# yearBuilt                           0
# bedrooms                            0
# bathrooms                           0
# squareFootage                       0
# lotSize                             0
# features.floorCount                 0
# features.garageSpaces               0
# features.unitCount                  0
# taxAssessments.2019.year            0
# taxAssessments.2019.value           0
# taxAssessments.2022.year            0
# taxAssessments.2022.value           0
# taxAssessments.2022.land            0
# taxAssessments.2022.improvements    0
# taxAssessments.2023.year            0
# taxAssessments.2023.value           0
# ...

# %%
df_clean.columns
# Out:
# Index(['id', 'formattedAddress', 'addressLine1', 'city', 'state', 'zipCode',
#        'county', 'latitude', 'longitude', 'yearBuilt',
#        ...
#        'propertyTaxes.2009.year', 'propertyTaxes.2009.total',
#        'taxAssessments.2010.year', 'taxAssessments.2010.value',
#        'taxAssessments.2011.year', 'taxAssessments.2011.value',
#        'taxAssessments.2011.land', 'taxAssessments.2011.improvements',
#        'propertyTaxes.2011.year', 'propertyTaxes.2011.total'],
#       dtype='object', length=103)

# %%
#estimate database. it will use the database above to get value of the prediction. It will be added to the column to be used as trainning

for 


url = "https://api.rentcast.io/v1/avm/rent/long-term?latitude=27.08556&longitude=-82.15281&propertyType=Single%20Family&compCount=25"
headers = {
    "accept": "application/json",
    "X-Api-Key": "dcc30d3e7e454610af41d9e6ddddeea7"
}

response = requests.get(url, headers=headers)

print(response.text)
